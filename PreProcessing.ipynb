# %% [markdown]
# # This program processes FASTA files for analysis

# %% [markdown]
# ## Parse FASTA File and Match Taxonomic Data

# %%
#### import os
import csv
import pandas as pd
from collections import defaultdict
from pathlib import Path
import sqlite3
from Bio import SeqIO
import re
import os

# for debugging
from itertools import islice

# %% [markdown]
# ### Developing Tree Model "taxo_search_tree" for Fast Taxonomic Lookup

# %%
# Table containing all taxonomic relationships from ICTV
taxonomy_table = pd.read_csv("taxonomy_table.csv", index_col=0)

taxonomy_table

# %%
# extract info from taxonomy_table and build lookup tree

# define tree
taxo_search_tree = {}

# Get column names for labeling
column_names = taxonomy_table.columns

# iterate through entire table and define relationships

# itertuples is faster for row iteration than pandas series
for row_tuple in taxonomy_table.itertuples(index=False, name = None):

    # Iterate through levels (EXCLUDE SUBLEVELS) in reverse order (known size of row = 15)
    for i in range(14,-2,-1):

        raw_value = row_tuple[i]
    
        current_level = column_names[i].lower()
        
        if pd.notna(raw_value):
            current = raw_value.lower()

        # If at the highest level just report level
        if i == 0:
            taxo_search_tree[current] = ("NA",current_level)

            
        if current not in taxo_search_tree:
            
            # Find the nearest parent (look backwards)
            for j in range(i - 1, -1, -1):
                parent_val = row_tuple[j]
                if pd.notna(parent_val):
                    taxo_search_tree[current] = (parent_val.lower(),current_level)
                    break
                elif j == 0:

                    # If no level above it just report level
                    taxo_search_tree[current] = ("None",current_level)
                    break

# Completed tree is named: taxo_search_tree


# Structure is key: (Parent, key's level)

# %%
taxo_search_tree

# %% [markdown]
# ### Parse FASTA files into table

# %%
# Point at folder with fasta files
fasta_dir = "virusDB/NCBI_Protein_Fasta"

# Grab all Fasta files paths

fasta_paths = list(Path(fasta_dir).glob(f'*.{"fsa_aa"}'))

# %%
# To determine if entry in taxo_search_tree

def find_taxo_key(words, taxo_search_tree):
    # Checks all consecutive word combinations in the label against the tree keys
    # Returns the longest matching key found

    words = words.split()

    N = len(words)
    best_match = None
    
    # 1. Generate Combinations and Search
    # Iterate through all possible starting positions (i)
    for i in range(N):
        # Iterate through all possible ending positions (j)
        # Note: We iterate from the start of the combination (i) to the end (N)
        for j in range(i, N):
            
            # Combine the words from index i to j (inclusive)
            candidate = " ".join(words[i : j + 1])
            
            # 2. O(1) Dictionary Lookup
            if candidate in taxo_search_tree:
                # Update the best match (we prefer longer matches)
                if best_match is None or len(candidate) > len(best_match):
                    best_match = candidate
                    
    return best_match

# %% [markdown]
# ### Generate New Dataframe From FASTA Files

# %%
def get_taxonomy (key):

    taxonomy = {}

    current = key

    # While there is a higher level defined
    while (current != "NA" and current in taxo_search_tree):
        
        taxonomy[taxo_search_tree[current][1]] = current

        current = taxo_search_tree[current][0]

    return taxonomy

# %%
# GENERATE TABLE WITH NEW WITH NEW DATA


output_file = "virus_taxonomy_table.csv"
batch_size = 100000
rows = []

# islice(iterator, stop) gets items from the iterator until 'stop' is reached.
for path in fasta_paths:
    for record in SeqIO.parse(path, "fasta"):
        full_header = record.description

        # extract organism name inside brackets using regex
        match = re.search(r'\[(.+?)\]', full_header)
        organism = match.group(1) if match else ""

        # Find the longest consecutive substring that is in the tree
        taxo_key = find_taxo_key(organism.lower(),taxo_search_tree)

        # Construct the columns
        row = {
            "protein_id": record.id,
            "protein_seq": str(record.seq),     
            "realm": "",
            "subrealm": "",
            "kingdom": "",
            "subkingdom": "",
            "phylum": "",
            "subphylum": "",
            "class": "",
            "subclass": "",
            "order": "",
            "suborder": "",
            "family": "",
            "subfamily": "",
            "genus": "",
            "subgenus": "",
            "species": ""
        }

        # Updates all taxonomy levels
        if taxo_key in taxo_search_tree:
        
            # Get dict of taxonomy
            taxonomy = get_taxonomy(taxo_key)
    
            # Update all taxonomic information
            for level in taxonomy:
                row[level] = taxonomy[level]
                
            rows.append(row)

        # Stores every time batch size is reached
        if len(rows) >= batch_size:
            # Convert rows to DataFrame
            df_chunk = pd.DataFrame(rows)
            
            # Determine if we need a header (only if file doesn't exist yet)
            write_header = not os.path.exists(output_file)
            
            # Write to CSV in 'append' mode
            df_chunk.to_csv(output_file, mode='a', index=False, header=write_header)
            
            print(f"Flushed {len(rows)} rows to {output_file}")
            
            # 3. CLEAR BUFFER (Crucial for freeing memory)
            rows = []

# Add whatever is left over
if rows:
    df_chunk = pd.DataFrame(rows)
    write_header = not os.path.exists(output_file)
    df_chunk.to_csv(output_file, mode='a', index=False, header=write_header)

# %% [markdown]
# ### Generate dataframe from old data

# %%
# REFORMAT OLD DATA

output_file = "irus_taxonomy_table.csv"

# NOTE: Faster the larger the chunk_size but limited by vectorized compute units and RAM
chunk_size = 100000


old_virus_db = pd.read_csv("/project/jespinoza_1537/GENOMESDB/virusDB/www.genome.jp/sorted.csv", chunksize = chunk_size, on_bad_lines='skip')


for chunk in old_virus_db:

    rows = []

    # Fast vectorization to extract lowest taxonomy level
    last_virus_entry = chunk["VIRUSES"].str.split('; ').str[-1].str.lower().fillna("")

    first_ids = chunk["PROTEIN_ID"].str.split(' ').str[0]

    sequences = chunk["PROTEIN_SEQUENCE"]

    # Fast vectorization to check in tree
    keys = last_virus_entry.apply(lambda x: find_taxo_key(x,taxo_search_tree))
    
    for protein_id, sequence, key in zip(first_ids, sequences, keys):

        # Construct the columns (NOTE: entry[6] is protein sequences in old table)
        row = {
            "protein_id": protein_id,
            "protein_seq": sequence,     
            "realm": "",
            "subrealm": "",
            "kingdom": "",
            "subkingdom": "",
            "phylum": "",
            "subphylum": "",
            "class": "",
            "subclass": "",
            "order": "",
            "suborder": "",
            "family": "",
            "subfamily": "",
            "genus": "",
            "subgenus": "",
            "species": ""
        }

        # Updates all taxonomy levels
        if key in taxo_search_tree:
        
            # Get dict of taxonomy
            taxonomy = get_taxonomy(key)
    
            # Update all taxonomic information
            for level in taxonomy:
                row[level] = taxonomy[level]
                
            rows.append(row)

        
    df_chunk = pd.DataFrame(rows)
        
    # Determine if we need a header (only if file doesn't exist yet)
    write_header = not os.path.exists(output_file)
    
    # Write to CSV in 'append' mode
    df_chunk.to_csv(output_file, mode='a', index=False, header=write_header)
    
    print(f"Flushed {len(rows)} rows to {output_file}")
        

# Add whatever is left over
if rows:
    df_chunk = pd.DataFrame(rows)
    write_header = not os.path.exists(output_file)
    df_chunk.to_csv(output_file, mode='a', index=False, header=write_header)

# %%
chunk_size = 100000

old_virus_db = pd.read_csv("/project/jespinoza_1537/GENOMESDB/virusDB/www.genome.jp/sorted.csv", chunksize = chunk_size, on_bad_lines='skip')

counter = 0
not_found = 0


for chunk in old_virus_db:

    last_virus_entry = chunk["VIRUSES"].str.split('; ').str[-1].str.lower().fillna("")

    # Fast vectorization to check in tree
    matches = last_virus_entry.apply(lambda x: find_taxo_key(x,taxo_search_tree)).isin(taxo_search_tree)

    
    # Sums total found
    chunk_matches = matches.sum()
    
    counter += chunk_matches
    not_found += (chunk_size - chunk_matches)

print(f"Total of {counter} valid IDs; Total of {not_found} invalid IDs")

# %%
test = pd.read_csv("/project/jespinoza_1537/GENOMESDB/virusDB/www.genome.jp/sorted.csv", nrows = 50)
test

# %%
pd.read_csv("virus_taxonomy_table.csv", nrows = 100000, dtype=str)
